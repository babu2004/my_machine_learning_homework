# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv')

# %%
del df['num_doors']
df.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive
# 1          17.8        2007     USA  Gasoline  Front-wheel drive
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive
# 3          20.2        2009     USA    Diesel    All-wheel drive
# 4          14.4        2009  Europe  Gasoline    All-wheel drive
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# 3            16.912736
# 4            12.488369

# %%
df = df.fillna(0)

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train,df_test=train_test_split(df,test_size=0.2,random_state=1)
df_train,df_val = train_test_split(df_full_train,test_size=0.25,random_state=1)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.fuel_efficiency_mpg.values
y_val = df_val.fuel_efficiency_mpg.values
y_test = df_test.fuel_efficiency_mpg.values

# %%
del df_train['fuel_efficiency_mpg']
del df_val['fuel_efficiency_mpg']
del df_test['fuel_efficiency_mpg']

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import mean_squared_error

# %% [markdown]
# now convert the dataframe into dictionaries

# %%
train_dicts = df_train.to_dict(orient='records')
train_dicts
# Out:
# [{'engine_displacement': 120,
#   'num_cylinders': 5.0,
#   'horsepower': 169.0,
#   'vehicle_weight': 2966.67950463456,
#   'acceleration': 13.9,
#   'model_year': 2005,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 3.0,
#   'horsepower': 143.0,
#   'vehicle_weight': 2950.822121334588,
#   'acceleration': 17.1,
#   'model_year': 2013,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 6.0,
#   'horsepower': 180.0,
#   'vehicle_weight': 3078.221669239548,
#   'acceleration': 17.4,
#   'model_year': 2007,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 280,
#   'num_cylinders': 5.0,
#   'horsepower': 174.0,
#   'vehicle_weight': 2797.9917925588984,
#   'acceleration': 0.0,
#   'model_year': 2016,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 4.0,
#   'horsepower': 133.0,
#   'vehicle_weight': 2362.4269297797937,
#   'acceleration': 16.3,
#   'model_year': 2010,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 0.0,
#   'horsepower': 180.0,
#   'vehicle_weight': 2150.4126295486194,
#   'acceleration': 13.4,
#   'model_year': 2019,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 7.0,
#   'horsepower': 87.0,
#   'vehicle_weight': 2969.4043298012853,
#   'acceleration': 11.3,
#   'model_year': 2007,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 5.0,
#   'horsepower': 103.0,
#   'vehicle_weight': 2941.587292544564,
#   'acceleration': 13.0,
#   'model_year': 2003,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 5.0,
#   'horsepower': 175.0,
#   'vehicle_weight': 2573.379139664969,
#   'acceleration': 16.0,
#   'model_year': 2022,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 130,
#   'num_cylinders': 5.0,
#   'horsepower': 177.0,
#   'vehicle_weight': 3471.43624178046,
#   'acceleration': 16.5,
#   'model_year': 2019,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 3.0,
#   'horsepower': 133.0,
#   'vehicle_weight': 3360.818964186123,
#   'acceleration': 17.3,
#   'model_year': 2001,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 4.0,
#   'horsepower': 155.0,
#   'vehicle_weight': 2773.265064356561,
#   'acceleration': 15.1,
#   'model_year': 2015,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 2.0,
#   'horsepower': 162.0,
#   'vehicle_weight': 2459.4453233435097,
#   'acceleration': 13.1,
#   'model_year': 2019,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 1.0,
#   'horsepower': 164.0,
#   'vehicle_weight': 3196.269981620835,
#   'acceleration': 11.8,
#   'model_year': 2020,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 350,
#   'num_cylinders': 6.0,
#   'horsepower': 153.0,
#   'vehicle_weight': 3901.949846504269,
#   'acceleration': 11.1,
#   'model_year': 2015,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 300,
#   'num_cylinders': 3.0,
#   'horsepower': 102.0,
#   'vehicle_weight': 2769.429335440867,
#   'acceleration': 12.0,
#   'model_year': 2015,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 3.0,
#   'horsepower': 153.0,
#   'vehicle_weight': 2999.5550297165096,
#   'acceleration': 15.9,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 2.0,
#   'horsepower': 142.0,
#   'vehicle_weight': 2828.2929473940885,
#   'acceleration': 0.0,
#   'model_year': 2022,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 2.0,
#   'horsepower': 106.0,
#   'vehicle_weight': 2664.5076338245663,
#   'acceleration': 16.3,
#   'model_year': 2011,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 90,
#   'num_cylinders': 4.0,
#   'horsepower': 201.0,
#   'vehicle_weight': 3406.4065913770296,
#   'acceleration': 17.6,
#   'model_year': 2010,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 290,
#   'num_cylinders': 2.0,
#   'horsepower': 151.0,
#   'vehicle_weight': 2380.2234679367784,
#   'acceleration': 14.7,
#   'model_year': 2019,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 2.0,
#   'horsepower': 133.0,
#   'vehicle_weight': 3250.5217277323354,
#   'acceleration': 14.1,
#   'model_year': 2014,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 1.0,
#   'horsepower': 93.0,
#   'vehicle_weight': 3287.7462721801617,
#   'acceleration': 8.8,
#   'model_year': 2009,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 4.0,
#   'horsepower': 145.0,
#   'vehicle_weight': 3549.027959078847,
#   'acceleration': 0.0,
#   'model_year': 2002,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 2.0,
#   'horsepower': 138.0,
#   'vehicle_weight': 3222.5694656755986,
#   'acceleration': 17.0,
#   'model_year': 2014,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 2.0,
#   'horsepower': 172.0,
#   'vehicle_weight': 2829.081145545386,
#   'acceleration': 13.7,
#   'model_year': 2001,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 5.0,
#   'horsepower': 163.0,
#   'vehicle_weight': 3042.6746109626856,
#   'acceleration': 14.8,
#   'model_year': 2012,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 3.0,
#   'horsepower': 179.0,
#   'vehicle_weight': 3080.8697829511875,
#   'acceleration': 13.0,
#   'model_year': 2013,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 5.0,
#   'horsepower': 168.0,
#   'vehicle_weight': 2500.398570104473,
#   'acceleration': 14.1,
#   'model_year': 2022,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 8.0,
#   'horsepower': 170.0,
#   'vehicle_weight': 2897.112576449679,
#   'acceleration': 14.2,
#   'model_year': 2014,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 6.0,
#   'horsepower': 195.0,
#   'vehicle_weight': 2553.489297555472,
#   'acceleration': 12.8,
#   'model_year': 2009,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 6.0,
#   'horsepower': 102.0,
#   'vehicle_weight': 3070.1364786374734,
#   'acceleration': 0.0,
#   'model_year': 2001,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 2.0,
#   'horsepower': 136.0,
#   'vehicle_weight': 2544.818997580292,
#   'acceleration': 14.5,
#   'model_year': 2021,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 3.0,
#   'horsepower': 155.0,
#   'vehicle_weight': 2543.3487181680457,
#   'acceleration': 17.4,
#   'model_year': 2009,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 1.0,
#   'horsepower': 153.0,
#   'vehicle_weight': 2500.019549303523,
#   'acceleration': 12.8,
#   'model_year': 2004,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 4.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3857.783903078682,
#   'acceleration': 12.8,
#   'model_year': 2019,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 3.0,
#   'horsepower': 117.0,
#   'vehicle_weight': 2887.0719066102884,
#   'acceleration': 21.0,
#   'model_year': 2012,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 6.0,
#   'horsepower': 132.0,
#   'vehicle_weight': 2868.94694236062,
#   'acceleration': 0.0,
#   'model_year': 2018,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 2.0,
#   'horsepower': 149.0,
#   'vehicle_weight': 2620.1157085772425,
#   'acceleration': 0.0,
#   'model_year': 2010,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 3.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2710.759701103073,
#   'acceleration': 12.7,
#   'model_year': 2007,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 110,
#   'num_cylinders': 7.0,
#   'horsepower': 104.0,
#   'vehicle_weight': 3084.839379984366,
#   'acceleration': 17.9,
#   'model_year': 2018,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 0.0,
#   'horsepower': 136.0,
#   'vehicle_weight': 3096.6418363622024,
#   'acceleration': 19.3,
#   'model_year': 2017,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 6.0,
#   'horsepower': 128.0,
#   'vehicle_weight': 2627.31869107166,
#   'acceleration': 11.9,
#   'model_year': 2011,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 320,
#   'num_cylinders': 3.0,
#   'horsepower': 121.0,
#   'vehicle_weight': 2533.143365382552,
#   'acceleration': 12.1,
#   'model_year': 2017,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 4.0,
#   'horsepower': 122.0,
#   'vehicle_weight': 3106.239166620779,
#   'acceleration': 19.2,
#   'model_year': 2003,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 5.0,
#   'horsepower': 102.0,
#   'vehicle_weight': 2609.6031548314663,
#   'acceleration': 18.1,
#   'model_year': 2002,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 4.0,
#   'horsepower': 122.0,
#   'vehicle_weight': 2916.4491027903678,
#   'acceleration': 17.5,
#   'model_year': 2016,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 3.0,
#   'horsepower': 151.0,
#   'vehicle_weight': 2517.98834361764,
#   'acceleration': 15.0,
#   'model_year': 2012,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 2.0,
#   'horsepower': 161.0,
#   'vehicle_weight': 3531.6832573085085,
#   'acceleration': 15.1,
#   'model_year': 2003,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 4.0,
#   'horsepower': 147.0,
#   'vehicle_weight': 2570.4140658318865,
#   'acceleration': 14.5,
#   'model_year': 2010,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 5.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3315.182857883409,
#   'acceleration': 13.5,
#   'model_year': 2019,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 3.0,
#   'horsepower': 194.0,
#   'vehicle_weight': 3612.4547360309166,
#   'acceleration': 0.0,
#   'model_year': 2001,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 0.0,
#   'horsepower': 133.0,
#   'vehicle_weight': 2866.200162641024,
#   'acceleration': 13.2,
#   'model_year': 2007,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 0.0,
#   'horsepower': 152.0,
#   'vehicle_weight': 2733.538665812652,
#   'acceleration': 19.7,
#   'model_year': 2009,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 5.0,
#   'horsepower': 137.0,
#   'vehicle_weight': 3284.5574011685867,
#   'acceleration': 13.6,
#   'model_year': 2001,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 10.0,
#   'horsepower': 133.0,
#   'vehicle_weight': 3553.842865429803,
#   'acceleration': 16.1,
#   'model_year': 2022,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 3.0,
#   'horsepower': 114.0,
#   'vehicle_weight': 2742.4841150671027,
#   'acceleration': 16.3,
#   'model_year': 2022,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 3.0,
#   'horsepower': 138.0,
#   'vehicle_weight': 3215.0255349136637,
#   'acceleration': 14.8,
#   'model_year': 2000,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 320,
#   'num_cylinders': 5.0,
#   'horsepower': 90.0,
#   'vehicle_weight': 3050.960697651394,
#   'acceleration': 18.9,
#   'model_year': 2005,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 3.0,
#   'horsepower': 160.0,
#   'vehicle_weight': 2454.1891881715924,
#   'acceleration': 12.8,
#   'model_year': 2017,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 130,
#   'num_cylinders': 6.0,
#   'horsepower': 124.0,
#   'vehicle_weight': 3402.600468102833,
#   'acceleration': 16.7,
#   'model_year': 2004,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 1.0,
#   'horsepower': 201.0,
#   'vehicle_weight': 2647.0768778928737,
#   'acceleration': 12.5,
#   'model_year': 2001,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 110,
#   'num_cylinders': 7.0,
#   'horsepower': 124.0,
#   'vehicle_weight': 2292.586181586986,
#   'acceleration': 19.7,
#   'model_year': 2021,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 8.0,
#   'horsepower': 143.0,
#   'vehicle_weight': 2900.3240852502727,
#   'acceleration': 11.8,
#   'model_year': 2021,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 4.0,
#   'horsepower': 179.0,
#   'vehicle_weight': 2631.0652035914763,
#   'acceleration': 16.0,
#   'model_year': 2006,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 3.0,
#   'horsepower': 180.0,
#   'vehicle_weight': 3580.2928100247627,
#   'acceleration': 14.8,
#   'model_year': 2015,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 4.0,
#   'horsepower': 168.0,
#   'vehicle_weight': 2428.6580426979563,
#   'acceleration': 15.8,
#   'model_year': 2011,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 1.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3174.4259170596915,
#   'acceleration': 16.2,
#   'model_year': 2015,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 6.0,
#   'horsepower': 121.0,
#   'vehicle_weight': 2225.120847855977,
#   'acceleration': 14.3,
#   'model_year': 2023,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 4.0,
#   'horsepower': 117.0,
#   'vehicle_weight': 3122.1518450411054,
#   'acceleration': 10.9,
#   'model_year': 2016,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 4.0,
#   'horsepower': 140.0,
#   'vehicle_weight': 2715.425462547724,
#   'acceleration': 15.3,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 5.0,
#   'horsepower': 145.0,
#   'vehicle_weight': 3609.891257881932,
#   'acceleration': 0.0,
#   'model_year': 2013,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 0.0,
#   'horsepower': 110.0,
#   'vehicle_weight': 3199.339482594565,
#   'acceleration': 0.0,
#   'model_year': 2013,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 8.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2668.863603095819,
#   'acceleration': 14.0,
#   'model_year': 2005,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 3.0,
#   'horsepower': 172.0,
#   'vehicle_weight': 3237.550439905122,
#   'acceleration': 17.0,
#   'model_year': 2000,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 4.0,
#   'horsepower': 186.0,
#   'vehicle_weight': 2069.8476258837063,
#   'acceleration': 10.3,
#   'model_year': 2022,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 4.0,
#   'horsepower': 153.0,
#   'vehicle_weight': 2676.619300937642,
#   'acceleration': 15.8,
#   'model_year': 2003,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 4.0,
#   'horsepower': 160.0,
#   'vehicle_weight': 3039.4896432766877,
#   'acceleration': 0.0,
#   'model_year': 2009,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 4.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3730.351063796101,
#   'acceleration': 0.0,
#   'model_year': 2018,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 1.0,
#   'horsepower': 138.0,
#   'vehicle_weight': 3093.084263017342,
#   'acceleration': 0.0,
#   'model_year': 2021,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 5.0,
#   'horsepower': 172.0,
#   'vehicle_weight': 2902.8763443413545,
#   'acceleration': 15.3,
#   'model_year': 2013,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 1.0,
#   'horsepower': 170.0,
#   'vehicle_weight': 3083.47215431077,
#   'acceleration': 11.9,
#   'model_year': 2005,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 4.0,
#   'horsepower': 229.0,
#   'vehicle_weight': 4174.489270180548,
#   'acceleration': 12.2,
#   'model_year': 2001,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 5.0,
#   'horsepower': 178.0,
#   'vehicle_weight': 2897.219431601042,
#   'acceleration': 10.0,
#   'model_year': 2009,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 4.0,
#   'horsepower': 117.0,
#   'vehicle_weight': 1818.9926157516693,
#   'acceleration': 9.8,
#   'model_year': 2004,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 2.0,
#   'horsepower': 186.0,
#   'vehicle_weight': 3200.9389657798524,
#   'acceleration': 15.8,
#   'model_year': 2001,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 2.0,
#   'horsepower': 143.0,
#   'vehicle_weight': 3242.7271302722334,
#   'acceleration': 14.5,
#   'model_year': 2009,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 2.0,
#   'horsepower': 165.0,
#   'vehicle_weight': 3661.891795544169,
#   'acceleration': 0.0,
#   'model_year': 2017,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 5.0,
#   'horsepower': 144.0,
#   'vehicle_weight': 2828.316640621033,
#   'acceleration': 11.8,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 6.0,
#   'horsepower': 115.0,
#   'vehicle_weight': 2911.625226933408,
#   'acceleration': 12.1,
#   'model_year': 2019,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 60,
#   'num_cylinders': 5.0,
#   'horsepower': 154.0,
#   'vehicle_weight': 3399.676318635893,
#   'acceleration': 16.2,
#   'model_year': 2009,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 7.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 4447.5238647055685,
#   'acceleration': 15.2,
#   'model_year': 2001,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 130,
#   'num_cylinders': 4.0,
#   'horsepower': 185.0,
#   'vehicle_weight': 2607.9543545296688,
#   'acceleration': 0.0,
#   'model_year': 2006,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 2.0,
#   'horsepower': 125.0,
#   'vehicle_weight': 2682.383913017531,
#   'acceleration': 16.7,
#   'model_year': 2005,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 7.0,
#   'horsepower': 186.0,
#   'vehicle_weight': 3572.727628474384,
#   'acceleration': 18.2,
#   'model_year': 2006,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 6.0,
#   'horsepower': 207.0,
#   'vehicle_weight': 2639.692336286209,
#   'acceleration': 15.6,
#   'model_year': 2010,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 110,
#   'num_cylinders': 3.0,
#   'horsepower': 128.0,
#   'vehicle_weight': 3873.9059943401726,
#   'acceleration': 14.4,
#   'model_year': 2017,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 3.0,
#   'horsepower': 135.0,
#   'vehicle_weight': 2657.524923605972,
#   'acceleration': 0.0,
#   'model_year': 2019,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 8.0,
#   'horsepower': 139.0,
#   'vehicle_weight': 3230.590185807569,
#   'acceleration': 14.7,
#   'model_year': 2019,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 130,
#   'num_cylinders': 7.0,
#   'horsepower': 187.0,
#   'vehicle_weight': 2626.836072222087,
#   'acceleration': 15.1,
#   'model_year': 2012,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 6.0,
#   'horsepower': 117.0,
#   'vehicle_weight': 3520.2237973572446,
#   'acceleration': 16.1,
#   'model_year': 2000,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 3.0,
#   'horsepower': 147.0,
#   'vehicle_weight': 2556.687575086716,
#   'acceleration': 11.8,
#   'model_year': 2009,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 2.0,
#   'horsepower': 174.0,
#   'vehicle_weight': 3687.088635012163,
#   'acceleration': 18.6,
#   'model_year': 2021,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 1.0,
#   'horsepower': 154.0,
#   'vehicle_weight': 3669.086729131214,
#   'acceleration': 15.1,
#   'model_year': 2015,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 3.0,
#   'horsepower': 115.0,
#   'vehicle_weight': 2957.2477943418307,
#   'acceleration': 14.6,
#   'model_year': 2019,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 2.0,
#   'horsepower': 121.0,
#   'vehicle_weight': 3453.6745312417006,
#   'acceleration': 14.8,
#   'model_year': 2003,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 5.0,
#   'horsepower': 161.0,
#   'vehicle_weight': 3022.1488395013157,
#   'acceleration': 14.9,
#   'model_year': 2021,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 3.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2135.0886555892303,
#   'acceleration': 19.5,
#   'model_year': 2022,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 80,
#   'num_cylinders': 3.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3336.1703528829403,
#   'acceleration': 17.2,
#   'model_year': 2009,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 70,
#   'num_cylinders': 3.0,
#   'horsepower': 157.0,
#   'vehicle_weight': 2333.467773340405,
#   'acceleration': 14.5,
#   'model_year': 2016,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 4.0,
#   'horsepower': 147.0,
#   'vehicle_weight': 3532.5375100494143,
#   'acceleration': 16.9,
#   'model_year': 2007,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 0.0,
#   'horsepower': 166.0,
#   'vehicle_weight': 2396.251595348677,
#   'acceleration': 0.0,
#   'model_year': 2014,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 100,
#   'num_cylinders': 4.0,
#   'horsepower': 140.0,
#   'vehicle_weight': 2765.774311225549,
#   'acceleration': 14.6,
#   'model_year': 2006,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 1.0,
#   'horsepower': 140.0,
#   'vehicle_weight': 2571.086616510185,
#   'acceleration': 16.0,
#   'model_year': 2014,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 120,
#   'num_cylinders': 2.0,
#   'horsepower': 130.0,
#   'vehicle_weight': 2959.729934611049,
#   'acceleration': 15.5,
#   'model_year': 2011,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 4.0,
#   'horsepower': 101.0,
#   'vehicle_weight': 3145.998117591521,
#   'acceleration': 11.5,
#   'model_year': 2005,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 0.0,
#   'horsepower': 168.0,
#   'vehicle_weight': 3739.804296912623,
#   'acceleration': 13.7,
#   'model_year': 2021,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 3.0,
#   'horsepower': 121.0,
#   'vehicle_weight': 3315.70172879404,
#   'acceleration': 12.6,
#   'model_year': 2016,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 280,
#   'num_cylinders': 4.0,
#   'horsepower': 98.0,
#   'vehicle_weight': 3263.4427422593103,
#   'acceleration': 15.0,
#   'model_year': 2013,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 2.0,
#   'horsepower': 117.0,
#   'vehicle_weight': 2443.50730288092,
#   'acceleration': 11.5,
#   'model_year': 2015,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 4.0,
#   'horsepower': 143.0,
#   'vehicle_weight': 3989.511347839062,
#   'acceleration': 14.3,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 5.0,
#   'horsepower': 134.0,
#   'vehicle_weight': 2630.4056656218827,
#   'acceleration': 12.5,
#   'model_year': 2012,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 6.0,
#   'horsepower': 153.0,
#   'vehicle_weight': 3373.4311600663013,
#   'acceleration': 11.9,
#   'model_year': 2017,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 3.0,
#   'horsepower': 193.0,
#   'vehicle_weight': 3144.971617613851,
#   'acceleration': 12.2,
#   'model_year': 2022,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 1.0,
#   'horsepower': 90.0,
#   'vehicle_weight': 3388.884018379308,
#   'acceleration': 16.0,
#   'model_year': 2023,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 3.0,
#   'horsepower': 150.0,
#   'vehicle_weight': 2526.182508499824,
#   'acceleration': 15.2,
#   'model_year': 2005,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 3.0,
#   'horsepower': 166.0,
#   'vehicle_weight': 3630.0284809308855,
#   'acceleration': 12.4,
#   'model_year': 2001,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 7.0,
#   'horsepower': 160.0,
#   'vehicle_weight': 3562.201851100356,
#   'acceleration': 0.0,
#   'model_year': 2002,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 4.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3064.9847934677923,
#   'acceleration': 12.7,
#   'model_year': 2003,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 80,
#   'num_cylinders': 0.0,
#   'horsepower': 156.0,
#   'vehicle_weight': 2420.127002727291,
#   'acceleration': 11.7,
#   'model_year': 2022,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 60,
#   'num_cylinders': 2.0,
#   'horsepower': 193.0,
#   'vehicle_weight': 2912.9234762785663,
#   'acceleration': 14.4,
#   'model_year': 2019,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 7.0,
#   'horsepower': 130.0,
#   'vehicle_weight': 2791.617871925648,
#   'acceleration': 15.9,
#   'model_year': 2018,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 2.0,
#   'horsepower': 136.0,
#   'vehicle_weight': 3694.7724278791625,
#   'acceleration': 13.8,
#   'model_year': 2001,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 2.0,
#   'horsepower': 122.0,
#   'vehicle_weight': 2885.713429893008,
#   'acceleration': 12.3,
#   'model_year': 2013,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 5.0,
#   'horsepower': 126.0,
#   'vehicle_weight': 2759.8333875373355,
#   'acceleration': 11.6,
#   'model_year': 2007,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 130,
#   'num_cylinders': 3.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3365.124312964436,
#   'acceleration': 17.9,
#   'model_year': 2002,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 6.0,
#   'horsepower': 151.0,
#   'vehicle_weight': 3498.931300814642,
#   'acceleration': 14.7,
#   'model_year': 2021,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 110,
#   'num_cylinders': 6.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3200.726305978916,
#   'acceleration': 13.0,
#   'model_year': 2007,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 7.0,
#   'horsepower': 102.0,
#   'vehicle_weight': 2861.7264816395764,
#   'acceleration': 15.4,
#   'model_year': 2012,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 5.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2428.321382466908,
#   'acceleration': 13.3,
#   'model_year': 2006,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 3.0,
#   'horsepower': 135.0,
#   'vehicle_weight': 2718.834972348582,
#   'acceleration': 13.4,
#   'model_year': 2003,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 3.0,
#   'horsepower': 166.0,
#   'vehicle_weight': 2536.6111707812747,
#   'acceleration': 16.6,
#   'model_year': 2008,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 3.0,
#   'horsepower': 170.0,
#   'vehicle_weight': 2505.354821550668,
#   'acceleration': 14.7,
#   'model_year': 2010,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 7.0,
#   'horsepower': 179.0,
#   'vehicle_weight': 3400.353931419809,
#   'acceleration': 13.1,
#   'model_year': 2008,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 1.0,
#   'horsepower': 188.0,
#   'vehicle_weight': 2390.320332843656,
#   'acceleration': 14.4,
#   'model_year': 2015,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 7.0,
#   'horsepower': 144.0,
#   'vehicle_weight': 2965.212754483249,
#   'acceleration': 17.8,
#   'model_year': 2001,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 2.0,
#   'horsepower': 149.0,
#   'vehicle_weight': 3505.7839962530343,
#   'acceleration': 13.6,
#   'model_year': 2018,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 6.0,
#   'horsepower': 154.0,
#   'vehicle_weight': 3102.901559632742,
#   'acceleration': 14.5,
#   'model_year': 2010,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 4.0,
#   'horsepower': 104.0,
#   'vehicle_weight': 2948.092715056828,
#   'acceleration': 16.7,
#   'model_year': 2017,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 12.0,
#   'horsepower': 171.0,
#   'vehicle_weight': 2915.3938384983285,
#   'acceleration': 13.7,
#   'model_year': 2011,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 3.0,
#   'horsepower': 202.0,
#   'vehicle_weight': 3041.6005127050776,
#   'acceleration': 15.5,
#   'model_year': 2017,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 2.0,
#   'horsepower': 136.0,
#   'vehicle_weight': 2783.7110053354527,
#   'acceleration': 0.0,
#   'model_year': 2020,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 3.0,
#   'horsepower': 129.0,
#   'vehicle_weight': 4138.376873388517,
#   'acceleration': 14.1,
#   'model_year': 2001,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 5.0,
#   'horsepower': 122.0,
#   'vehicle_weight': 2759.74744662664,
#   'acceleration': 14.6,
#   'model_year': 2013,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 5.0,
#   'horsepower': 101.0,
#   'vehicle_weight': 3731.473905111399,
#   'acceleration': 0.0,
#   'model_year': 2002,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 2.0,
#   'horsepower': 114.0,
#   'vehicle_weight': 2147.289938809588,
#   'acceleration': 17.6,
#   'model_year': 2008,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 3.0,
#   'horsepower': 143.0,
#   'vehicle_weight': 2921.9903434641265,
#   'acceleration': 17.5,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 3.0,
#   'horsepower': 169.0,
#   'vehicle_weight': 3222.073264855782,
#   'acceleration': 19.3,
#   'model_year': 2009,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 310,
#   'num_cylinders': 1.0,
#   'horsepower': 161.0,
#   'vehicle_weight': 2918.307777747784,
#   'acceleration': 13.1,
#   'model_year': 2015,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 3.0,
#   'horsepower': 189.0,
#   'vehicle_weight': 2297.882478122827,
#   'acceleration': 13.5,
#   'model_year': 2016,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 5.0,
#   'horsepower': 169.0,
#   'vehicle_weight': 3751.996486771851,
#   'acceleration': 17.9,
#   'model_year': 2000,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 2.0,
#   'horsepower': 150.0,
#   'vehicle_weight': 2492.0295145283194,
#   'acceleration': 0.0,
#   'model_year': 2006,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 3.0,
#   'horsepower': 134.0,
#   'vehicle_weight': 3476.935468864884,
#   'acceleration': 10.2,
#   'model_year': 2005,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 7.0,
#   'horsepower': 109.0,
#   'vehicle_weight': 4126.979050698652,
#   'acceleration': 14.6,
#   'model_year': 2016,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 4.0,
#   'horsepower': 147.0,
#   'vehicle_weight': 2491.477969518409,
#   'acceleration': 13.4,
#   'model_year': 2007,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 6.0,
#   'horsepower': 143.0,
#   'vehicle_weight': 2545.9760185031937,
#   'acceleration': 12.3,
#   'model_year': 2015,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 1.0,
#   'horsepower': 109.0,
#   'vehicle_weight': 2703.399908387454,
#   'acceleration': 15.5,
#   'model_year': 2013,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 4.0,
#   'horsepower': 212.0,
#   'vehicle_weight': 3139.1912390664743,
#   'acceleration': 16.7,
#   'model_year': 2004,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 5.0,
#   'horsepower': 188.0,
#   'vehicle_weight': 2884.226318756615,
#   'acceleration': 18.4,
#   'model_year': 2003,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 3.0,
#   'horsepower': 153.0,
#   'vehicle_weight': 3032.2667989280385,
#   'acceleration': 14.3,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 6.0,
#   'horsepower': 155.0,
#   'vehicle_weight': 3417.526462497532,
#   'acceleration': 12.8,
#   'model_year': 2004,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 370,
#   'num_cylinders': 5.0,
#   'horsepower': 134.0,
#   'vehicle_weight': 3309.1023151026625,
#   'acceleration': 0.0,
#   'model_year': 2016,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 280,
#   'num_cylinders': 1.0,
#   'horsepower': 150.0,
#   'vehicle_weight': 3281.7931445171344,
#   'acceleration': 13.9,
#   'model_year': 2014,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 7.0,
#   'horsepower': 184.0,
#   'vehicle_weight': 3030.9648752787334,
#   'acceleration': 0.0,
#   'model_year': 2009,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 280,
#   'num_cylinders': 5.0,
#   'horsepower': 87.0,
#   'vehicle_weight': 2228.164314001735,
#   'acceleration': 14.0,
#   'model_year': 2021,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 4.0,
#   'horsepower': 125.0,
#   'vehicle_weight': 3589.358879690629,
#   'acceleration': 11.3,
#   'model_year': 2012,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 7.0,
#   'horsepower': 143.0,
#   'vehicle_weight': 2441.496241864477,
#   'acceleration': 17.9,
#   'model_year': 2003,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 2.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2972.3336783824025,
#   'acceleration': 16.4,
#   'model_year': 2021,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 3.0,
#   'horsepower': 130.0,
#   'vehicle_weight': 3374.316110710007,
#   'acceleration': 14.5,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 1.0,
#   'horsepower': 107.0,
#   'vehicle_weight': 2841.637418376827,
#   'acceleration': 16.3,
#   'model_year': 2009,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 4.0,
#   'horsepower': 140.0,
#   'vehicle_weight': 2315.3689983588697,
#   'acceleration': 8.4,
#   'model_year': 2021,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 4.0,
#   'horsepower': 171.0,
#   'vehicle_weight': 2728.9970214357563,
#   'acceleration': 0.0,
#   'model_year': 2016,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 0.0,
#   'horsepower': 132.0,
#   'vehicle_weight': 3939.901915877572,
#   'acceleration': 17.8,
#   'model_year': 2016,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 300,
#   'num_cylinders': 5.0,
#   'horsepower': 127.0,
#   'vehicle_weight': 3703.869908788861,
#   'acceleration': 7.4,
#   'model_year': 2003,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 3.0,
#   'horsepower': 95.0,
#   'vehicle_weight': 2497.440696399879,
#   'acceleration': 14.2,
#   'model_year': 2018,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 0.0,
#   'horsepower': 177.0,
#   'vehicle_weight': 2771.693034888444,
#   'acceleration': 14.8,
#   'model_year': 2001,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 2.0,
#   'horsepower': 121.0,
#   'vehicle_weight': 3344.7017049053948,
#   'acceleration': 16.5,
#   'model_year': 2001,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 4.0,
#   'horsepower': 146.0,
#   'vehicle_weight': 2962.54471993326,
#   'acceleration': 0.0,
#   'model_year': 2016,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 4.0,
#   'horsepower': 138.0,
#   'vehicle_weight': 2714.536778771385,
#   'acceleration': 15.0,
#   'model_year': 2002,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 4.0,
#   'horsepower': 147.0,
#   'vehicle_weight': 4132.260976168944,
#   'acceleration': 19.5,
#   'model_year': 2019,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 290,
#   'num_cylinders': 1.0,
#   'horsepower': 137.0,
#   'vehicle_weight': 2917.5293877609374,
#   'acceleration': 17.3,
#   'model_year': 2007,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 5.0,
#   'horsepower': 147.0,
#   'vehicle_weight': 2779.2760196599597,
#   'acceleration': 12.3,
#   'model_year': 2009,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 1.0,
#   'horsepower': 168.0,
#   'vehicle_weight': 2986.6023944926383,
#   'acceleration': 11.5,
#   'model_year': 2014,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 120,
#   'num_cylinders': 3.0,
#   'horsepower': 142.0,
#   'vehicle_weight': 3287.9321575423587,
#   'acceleration': 18.2,
#   'model_year': 2018,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 4.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3121.653108195651,
#   'acceleration': 15.3,
#   'model_year': 2011,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 3.0,
#   'horsepower': 148.0,
#   'vehicle_weight': 2641.2149138000023,
#   'acceleration': 7.0,
# ...
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 3.0,
#   'horsepower': 140.0,
#   'vehicle_weight': 4247.608156747391,
#   'acceleration': 13.0,
#   'model_year': 2004,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 2.0,
#   'horsepower': 155.0,
#   'vehicle_weight': 3076.185387042084,
#   'acceleration': 17.0,
#   'model_year': 2019,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 4.0,
#   'horsepower': 128.0,
#   'vehicle_weight': 3370.961905821891,
#   'acceleration': 10.3,
#   'model_year': 2003,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 6.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3016.863798998372,
#   'acceleration': 13.3,
#   'model_year': 2017,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 4.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2109.8732187123023,
#   'acceleration': 18.0,
#   'model_year': 2011,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 4.0,
#   'horsepower': 186.0,
#   'vehicle_weight': 2611.387314466448,
#   'acceleration': 17.5,
#   'model_year': 2020,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 6.0,
#   'horsepower': 141.0,
#   'vehicle_weight': 4030.566285177957,
#   'acceleration': 10.3,
#   'model_year': 2008,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 7.0,
#   'horsepower': 172.0,
#   'vehicle_weight': 2452.6836844463355,
#   'acceleration': 15.3,
#   'model_year': 2016,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 120,
#   'num_cylinders': 1.0,
#   'horsepower': 141.0,
#   'vehicle_weight': 2997.228845703816,
#   'acceleration': 14.5,
#   'model_year': 2021,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 4.0,
#   'horsepower': 115.0,
#   'vehicle_weight': 4457.44660764925,
#   'acceleration': 13.9,
#   'model_year': 2016,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 2.0,
#   'horsepower': 159.0,
#   'vehicle_weight': 3082.8043108511006,
#   'acceleration': 15.3,
#   'model_year': 2009,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 4.0,
#   'horsepower': 144.0,
#   'vehicle_weight': 3158.44079086634,
#   'acceleration': 13.7,
#   'model_year': 2010,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 280,
#   'num_cylinders': 3.0,
#   'horsepower': 165.0,
#   'vehicle_weight': 2132.7715106017117,
#   'acceleration': 13.2,
#   'model_year': 2018,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 1.0,
#   'horsepower': 145.0,
#   'vehicle_weight': 2805.924343202953,
#   'acceleration': 8.9,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 5.0,
#   'horsepower': 186.0,
#   'vehicle_weight': 3472.290568300881,
#   'acceleration': 20.4,
#   'model_year': 2018,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 2.0,
#   'horsepower': 116.0,
#   'vehicle_weight': 2830.2141636560395,
#   'acceleration': 16.4,
#   'model_year': 2010,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 350,
#   'num_cylinders': 6.0,
#   'horsepower': 151.0,
#   'vehicle_weight': 3026.883980170491,
#   'acceleration': 14.0,
#   'model_year': 2007,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 6.0,
#   'horsepower': 138.0,
#   'vehicle_weight': 2897.6765578054324,
#   'acceleration': 11.2,
#   'model_year': 2006,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 110,
#   'num_cylinders': 3.0,
#   'horsepower': 128.0,
#   'vehicle_weight': 2572.7532487186786,
#   'acceleration': 16.9,
#   'model_year': 2001,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 2.0,
#   'horsepower': 161.0,
#   'vehicle_weight': 3143.461057605549,
#   'acceleration': 13.2,
#   'model_year': 2003,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 7.0,
#   'horsepower': 129.0,
#   'vehicle_weight': 2565.95147414962,
#   'acceleration': 17.7,
#   'model_year': 2003,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 6.0,
#   'horsepower': 162.0,
#   'vehicle_weight': 3610.2941231450586,
#   'acceleration': 17.1,
#   'model_year': 2001,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 2.0,
#   'horsepower': 209.0,
#   'vehicle_weight': 2288.934352430637,
#   'acceleration': 0.0,
#   'model_year': 2003,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 9.0,
#   'horsepower': 152.0,
#   'vehicle_weight': 3621.3584313053366,
#   'acceleration': 15.2,
#   'model_year': 2006,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 110,
#   'num_cylinders': 3.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2794.656333658625,
#   'acceleration': 0.0,
#   'model_year': 2008,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 6.0,
#   'horsepower': 185.0,
#   'vehicle_weight': 3874.515896743643,
#   'acceleration': 15.4,
#   'model_year': 2000,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 2.0,
#   'horsepower': 186.0,
#   'vehicle_weight': 3354.6039223891744,
#   'acceleration': 11.4,
#   'model_year': 2006,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 4.0,
#   'horsepower': 165.0,
#   'vehicle_weight': 3310.764962801274,
#   'acceleration': 10.5,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 4.0,
#   'horsepower': 142.0,
#   'vehicle_weight': 2765.4695407096992,
#   'acceleration': 11.5,
#   'model_year': 2020,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 110,
#   'num_cylinders': 2.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3102.7071319258825,
#   'acceleration': 15.1,
#   'model_year': 2009,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 130,
#   'num_cylinders': 0.0,
#   'horsepower': 152.0,
#   'vehicle_weight': 2672.12318874336,
#   'acceleration': 14.7,
#   'model_year': 2010,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 4.0,
#   'horsepower': 159.0,
#   'vehicle_weight': 4200.111075939867,
#   'acceleration': 12.8,
#   'model_year': 2004,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 3.0,
#   'horsepower': 173.0,
#   'vehicle_weight': 2582.781774557869,
#   'acceleration': 0.0,
#   'model_year': 2012,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 1.0,
#   'horsepower': 133.0,
#   'vehicle_weight': 4090.247601509672,
#   'acceleration': 14.7,
#   'model_year': 2015,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 3.0,
#   'horsepower': 127.0,
#   'vehicle_weight': 2198.6254314382904,
#   'acceleration': 0.0,
#   'model_year': 2001,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 5.0,
#   'horsepower': 164.0,
#   'vehicle_weight': 3209.241832102833,
#   'acceleration': 11.1,
#   'model_year': 2008,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 7.0,
#   'horsepower': 179.0,
#   'vehicle_weight': 3546.122222811928,
#   'acceleration': 11.6,
#   'model_year': 2018,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 5.0,
#   'horsepower': 132.0,
#   'vehicle_weight': 3515.490723191879,
#   'acceleration': 0.0,
#   'model_year': 2005,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 130,
#   'num_cylinders': 7.0,
#   'horsepower': 125.0,
#   'vehicle_weight': 3539.4830399607245,
#   'acceleration': 15.9,
#   'model_year': 2007,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 4.0,
#   'horsepower': 98.0,
#   'vehicle_weight': 3396.465225611827,
#   'acceleration': 13.5,
#   'model_year': 2019,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 120,
#   'num_cylinders': 5.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3753.273740549794,
#   'acceleration': 15.7,
#   'model_year': 2001,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 4.0,
#   'horsepower': 59.0,
#   'vehicle_weight': 3059.1059887155216,
#   'acceleration': 14.4,
#   'model_year': 2006,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 1.0,
#   'horsepower': 142.0,
#   'vehicle_weight': 2622.936600708895,
#   'acceleration': 12.5,
#   'model_year': 2002,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 70,
#   'num_cylinders': 8.0,
#   'horsepower': 138.0,
#   'vehicle_weight': 3043.695695886079,
#   'acceleration': 16.2,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 3.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3234.1029873851858,
#   'acceleration': 10.0,
#   'model_year': 2004,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 0.0,
#   'horsepower': 154.0,
#   'vehicle_weight': 2992.193771248432,
#   'acceleration': 12.8,
#   'model_year': 2011,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 5.0,
#   'horsepower': 196.0,
#   'vehicle_weight': 3377.922055920314,
#   'acceleration': 14.8,
#   'model_year': 2014,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 10.0,
#   'horsepower': 163.0,
#   'vehicle_weight': 3125.2010211397574,
#   'acceleration': 14.8,
#   'model_year': 2014,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 6.0,
#   'horsepower': 130.0,
#   'vehicle_weight': 2774.652859619128,
#   'acceleration': 11.9,
#   'model_year': 2011,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 130,
#   'num_cylinders': 2.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3262.111941322569,
#   'acceleration': 15.0,
#   'model_year': 2000,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 310,
#   'num_cylinders': 0.0,
#   'horsepower': 132.0,
#   'vehicle_weight': 2121.470254292444,
#   'acceleration': 13.5,
#   'model_year': 2004,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 7.0,
#   'horsepower': 149.0,
#   'vehicle_weight': 3163.2462124908684,
#   'acceleration': 13.3,
#   'model_year': 2020,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 8.0,
#   'horsepower': 160.0,
#   'vehicle_weight': 3287.674141423352,
#   'acceleration': 17.4,
#   'model_year': 2018,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 70,
#   'num_cylinders': 4.0,
#   'horsepower': 173.0,
#   'vehicle_weight': 2810.6787246995896,
#   'acceleration': 16.5,
#   'model_year': 2004,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 4.0,
#   'horsepower': 104.0,
#   'vehicle_weight': 3022.24645042498,
#   'acceleration': 9.9,
#   'model_year': 2009,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 3.0,
#   'horsepower': 160.0,
#   'vehicle_weight': 2814.729928090046,
#   'acceleration': 0.0,
#   'model_year': 2014,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 6.0,
#   'horsepower': 186.0,
#   'vehicle_weight': 3585.1380579449205,
#   'acceleration': 16.3,
#   'model_year': 2008,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 5.0,
#   'horsepower': 172.0,
#   'vehicle_weight': 3880.56812857786,
#   'acceleration': 16.0,
#   'model_year': 2008,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 8.0,
#   'horsepower': 156.0,
#   'vehicle_weight': 4060.7930947723225,
#   'acceleration': 0.0,
#   'model_year': 2022,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 130,
#   'num_cylinders': 6.0,
#   'horsepower': 151.0,
#   'vehicle_weight': 3550.82242445977,
#   'acceleration': 14.5,
#   'model_year': 2006,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 4.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3306.3540004068445,
#   'acceleration': 15.6,
#   'model_year': 2000,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 310,
#   'num_cylinders': 2.0,
#   'horsepower': 111.0,
#   'vehicle_weight': 3522.682332158088,
#   'acceleration': 20.4,
#   'model_year': 2010,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 3.0,
#   'horsepower': 175.0,
#   'vehicle_weight': 2854.106715111863,
#   'acceleration': 13.4,
#   'model_year': 2015,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 5.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2831.939210103963,
#   'acceleration': 16.0,
#   'model_year': 2005,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 130,
#   'num_cylinders': 4.0,
#   'horsepower': 150.0,
#   'vehicle_weight': 2702.262743201707,
#   'acceleration': 12.4,
#   'model_year': 2004,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  ...]

# %%
dv=DictVectorizer(sparse=False)
X_train = dv.fit_transform(train_dicts)

# %%
dv.get_feature_names_out()
# Out:
# array(['acceleration', 'drivetrain=All-wheel drive',
#        'drivetrain=Front-wheel drive', 'engine_displacement',
#        'fuel_type=Diesel', 'fuel_type=Gasoline', 'horsepower',
#        'model_year', 'num_cylinders', 'origin=Asia', 'origin=Europe',
#        'origin=USA', 'vehicle_weight'], dtype=object)

# %%
dt = DecisionTreeRegressor(max_depth=1)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
val_dicts = df_val.to_dict(orient='records')
val_dicts
# Out:
# [{'engine_displacement': 210,
#   'num_cylinders': 6.0,
#   'horsepower': 151.0,
#   'vehicle_weight': 2255.7503220401827,
#   'acceleration': 20.9,
#   'model_year': 2013,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 6.0,
#   'horsepower': 145.0,
#   'vehicle_weight': 2921.3282717888364,
#   'acceleration': 15.4,
#   'model_year': 2008,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 4.0,
#   'horsepower': 133.0,
#   'vehicle_weight': 2357.7875141078985,
#   'acceleration': 13.8,
#   'model_year': 2018,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 3.0,
#   'horsepower': 105.0,
#   'vehicle_weight': 2988.730169728115,
#   'acceleration': 16.0,
#   'model_year': 2012,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 3.0,
#   'horsepower': 93.0,
#   'vehicle_weight': 3174.840838312398,
#   'acceleration': 20.2,
#   'model_year': 2015,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 2.0,
#   'horsepower': 183.0,
#   'vehicle_weight': 2825.5689565345706,
#   'acceleration': 14.9,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 5.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2928.905284405099,
#   'acceleration': 14.8,
#   'model_year': 2009,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 3.0,
#   'horsepower': 160.0,
#   'vehicle_weight': 3397.1961113809816,
#   'acceleration': 15.4,
#   'model_year': 2006,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 3.0,
#   'horsepower': 142.0,
#   'vehicle_weight': 3820.829124358242,
#   'acceleration': 17.4,
#   'model_year': 2004,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 2.0,
#   'horsepower': 151.0,
#   'vehicle_weight': 2848.1782524550777,
#   'acceleration': 14.9,
#   'model_year': 2021,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 5.0,
#   'horsepower': 144.0,
#   'vehicle_weight': 4181.6835852953855,
#   'acceleration': 9.8,
#   'model_year': 2006,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 9.0,
#   'horsepower': 125.0,
#   'vehicle_weight': 2681.518452867256,
#   'acceleration': 14.9,
#   'model_year': 2019,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 70,
#   'num_cylinders': 3.0,
#   'horsepower': 172.0,
#   'vehicle_weight': 2789.1088471913577,
#   'acceleration': 9.3,
#   'model_year': 2011,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 100,
#   'num_cylinders': 4.0,
#   'horsepower': 80.0,
#   'vehicle_weight': 3352.916418687943,
#   'acceleration': 17.0,
#   'model_year': 2005,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 110,
#   'num_cylinders': 4.0,
#   'horsepower': 127.0,
#   'vehicle_weight': 3273.610751625405,
#   'acceleration': 19.3,
#   'model_year': 2009,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 300,
#   'num_cylinders': 5.0,
#   'horsepower': 145.0,
#   'vehicle_weight': 3443.5975632039126,
#   'acceleration': 14.7,
#   'model_year': 2018,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 3.0,
#   'horsepower': 179.0,
#   'vehicle_weight': 3052.9470220558464,
#   'acceleration': 18.0,
#   'model_year': 2010,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 1.0,
#   'horsepower': 131.0,
#   'vehicle_weight': 3202.6298526309647,
#   'acceleration': 11.6,
#   'model_year': 2019,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 2.0,
#   'horsepower': 160.0,
#   'vehicle_weight': 3517.247147629859,
#   'acceleration': 17.8,
#   'model_year': 2007,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 4.0,
#   'horsepower': 96.0,
#   'vehicle_weight': 2555.0759937019725,
#   'acceleration': 12.5,
#   'model_year': 2011,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 3.0,
#   'horsepower': 135.0,
#   'vehicle_weight': 2925.9007152589147,
#   'acceleration': 17.4,
#   'model_year': 2015,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 4.0,
#   'horsepower': 145.0,
#   'vehicle_weight': 2821.631444506445,
#   'acceleration': 15.2,
#   'model_year': 2018,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 2.0,
#   'horsepower': 131.0,
#   'vehicle_weight': 2736.156740141587,
#   'acceleration': 15.5,
#   'model_year': 2009,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 5.0,
#   'horsepower': 113.0,
#   'vehicle_weight': 3374.803064420992,
#   'acceleration': 15.4,
#   'model_year': 2015,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 5.0,
#   'horsepower': 150.0,
#   'vehicle_weight': 3138.224973592119,
#   'acceleration': 13.2,
#   'model_year': 2017,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 100,
#   'num_cylinders': 4.0,
#   'horsepower': 111.0,
#   'vehicle_weight': 2023.807547594512,
#   'acceleration': 17.4,
#   'model_year': 2020,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 3.0,
#   'horsepower': 139.0,
#   'vehicle_weight': 3021.4705264207746,
#   'acceleration': 15.1,
#   'model_year': 2004,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 330,
#   'num_cylinders': 3.0,
#   'horsepower': 207.0,
#   'vehicle_weight': 3486.549303555135,
#   'acceleration': 13.9,
#   'model_year': 2011,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 3.0,
#   'horsepower': 149.0,
#   'vehicle_weight': 3520.0985427612686,
#   'acceleration': 14.8,
#   'model_year': 2002,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 4.0,
#   'horsepower': 185.0,
#   'vehicle_weight': 4012.316736293076,
#   'acceleration': 0.0,
#   'model_year': 2020,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 1.0,
#   'horsepower': 122.0,
#   'vehicle_weight': 3319.0183103503923,
#   'acceleration': 15.1,
#   'model_year': 2007,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 4.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3004.5889977352103,
#   'acceleration': 11.8,
#   'model_year': 2010,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 0.0,
#   'horsepower': 152.0,
#   'vehicle_weight': 3453.207789279994,
#   'acceleration': 15.7,
#   'model_year': 2015,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 110,
#   'num_cylinders': 4.0,
#   'horsepower': 134.0,
#   'vehicle_weight': 3525.70989076538,
#   'acceleration': 13.5,
#   'model_year': 2007,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 8.0,
#   'horsepower': 119.0,
#   'vehicle_weight': 2900.6553422092197,
#   'acceleration': 19.2,
#   'model_year': 2018,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 4.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2729.6237411896427,
#   'acceleration': 13.2,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 2.0,
#   'horsepower': 185.0,
#   'vehicle_weight': 3211.8784330957697,
#   'acceleration': 15.0,
#   'model_year': 2016,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 4.0,
#   'horsepower': 179.0,
#   'vehicle_weight': 3017.849377180836,
#   'acceleration': 12.9,
#   'model_year': 2014,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 6.0,
#   'horsepower': 142.0,
#   'vehicle_weight': 3850.159565198597,
#   'acceleration': 12.7,
#   'model_year': 2010,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 8.0,
#   'horsepower': 157.0,
#   'vehicle_weight': 4045.251127001726,
#   'acceleration': 15.3,
#   'model_year': 2014,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 5.0,
#   'horsepower': 132.0,
#   'vehicle_weight': 2851.0421855856,
#   'acceleration': 17.7,
#   'model_year': 2014,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 4.0,
#   'horsepower': 197.0,
#   'vehicle_weight': 2844.210130188124,
#   'acceleration': 15.4,
#   'model_year': 2012,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 2.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3253.9025935297364,
#   'acceleration': 20.7,
#   'model_year': 2023,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 60,
#   'num_cylinders': 3.0,
#   'horsepower': 162.0,
#   'vehicle_weight': 2827.603275280178,
#   'acceleration': 15.1,
#   'model_year': 2006,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 2.0,
#   'horsepower': 171.0,
#   'vehicle_weight': 2617.1383055056267,
#   'acceleration': 13.1,
#   'model_year': 2008,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 6.0,
#   'horsepower': 146.0,
#   'vehicle_weight': 3623.1748971589273,
#   'acceleration': 16.6,
#   'model_year': 2022,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 8.0,
#   'horsepower': 109.0,
#   'vehicle_weight': 2841.2562957157784,
#   'acceleration': 16.1,
#   'model_year': 2015,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 3.0,
#   'horsepower': 165.0,
#   'vehicle_weight': 2511.1860310443367,
#   'acceleration': 14.1,
#   'model_year': 2008,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 0.0,
#   'horsepower': 124.0,
#   'vehicle_weight': 2519.1958229261973,
#   'acceleration': 0.0,
#   'model_year': 2010,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 4.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2592.6084822469666,
#   'acceleration': 17.1,
#   'model_year': 2013,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 4.0,
#   'horsepower': 149.0,
#   'vehicle_weight': 2675.631939322267,
#   'acceleration': 9.9,
#   'model_year': 2001,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 280,
#   'num_cylinders': 2.0,
#   'horsepower': 128.0,
#   'vehicle_weight': 2623.7411810162967,
#   'acceleration': 14.6,
#   'model_year': 2022,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 5.0,
#   'horsepower': 140.0,
#   'vehicle_weight': 3016.461135399279,
#   'acceleration': 10.5,
#   'model_year': 2006,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 4.0,
#   'horsepower': 205.0,
#   'vehicle_weight': 2902.024401991179,
#   'acceleration': 13.2,
#   'model_year': 2014,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 280,
#   'num_cylinders': 4.0,
#   'horsepower': 154.0,
#   'vehicle_weight': 2328.8919132971714,
#   'acceleration': 14.5,
#   'model_year': 2001,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 5.0,
#   'horsepower': 209.0,
#   'vehicle_weight': 2984.998708911169,
#   'acceleration': 15.1,
#   'model_year': 2021,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 40,
#   'num_cylinders': 5.0,
#   'horsepower': 157.0,
#   'vehicle_weight': 2942.639275115232,
#   'acceleration': 11.2,
#   'model_year': 2007,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 3.0,
#   'horsepower': 80.0,
#   'vehicle_weight': 3504.248301935137,
#   'acceleration': 14.5,
#   'model_year': 2019,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 4.0,
#   'horsepower': 165.0,
#   'vehicle_weight': 3375.2960616175824,
#   'acceleration': 14.1,
#   'model_year': 2019,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 120,
#   'num_cylinders': 4.0,
#   'horsepower': 123.0,
#   'vehicle_weight': 2219.6301319930744,
#   'acceleration': 13.7,
#   'model_year': 2021,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 4.0,
#   'horsepower': 187.0,
#   'vehicle_weight': 3325.764874061405,
#   'acceleration': 15.5,
#   'model_year': 2013,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 5.0,
#   'horsepower': 159.0,
#   'vehicle_weight': 3497.823916814365,
#   'acceleration': 0.0,
#   'model_year': 2010,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 5.0,
#   'horsepower': 140.0,
#   'vehicle_weight': 3596.825794121574,
#   'acceleration': 0.0,
#   'model_year': 2010,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 3.0,
#   'horsepower': 110.0,
#   'vehicle_weight': 3069.9563690544664,
#   'acceleration': 16.1,
#   'model_year': 2003,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 130,
#   'num_cylinders': 9.0,
#   'horsepower': 109.0,
#   'vehicle_weight': 4088.9447587227214,
#   'acceleration': 18.0,
#   'model_year': 2020,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 5.0,
#   'horsepower': 141.0,
#   'vehicle_weight': 2979.784665383784,
#   'acceleration': 16.1,
#   'model_year': 2007,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 0.0,
#   'horsepower': 130.0,
#   'vehicle_weight': 2602.541912964154,
#   'acceleration': 14.8,
#   'model_year': 2006,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 290,
#   'num_cylinders': 3.0,
#   'horsepower': 146.0,
#   'vehicle_weight': 2143.919077781052,
#   'acceleration': 15.6,
#   'model_year': 2019,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 5.0,
#   'horsepower': 115.0,
#   'vehicle_weight': 3245.30676717777,
#   'acceleration': 14.1,
#   'model_year': 2011,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 4.0,
#   'horsepower': 145.0,
#   'vehicle_weight': 2560.875259557665,
#   'acceleration': 15.6,
#   'model_year': 2010,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 3.0,
#   'horsepower': 144.0,
#   'vehicle_weight': 3423.670074018117,
#   'acceleration': 16.7,
#   'model_year': 2014,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 2.0,
#   'horsepower': 187.0,
#   'vehicle_weight': 3393.1364239047743,
#   'acceleration': 15.6,
#   'model_year': 2014,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 2.0,
#   'horsepower': 159.0,
#   'vehicle_weight': 2576.835535731921,
#   'acceleration': 13.3,
#   'model_year': 2015,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 10.0,
#   'horsepower': 166.0,
#   'vehicle_weight': 2204.0917976483065,
#   'acceleration': 16.9,
#   'model_year': 2022,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 2.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3298.446497994772,
#   'acceleration': 14.0,
#   'model_year': 2013,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 5.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3022.147274762914,
#   'acceleration': 18.8,
#   'model_year': 2006,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 0.0,
#   'horsepower': 163.0,
#   'vehicle_weight': 3244.2745775117955,
#   'acceleration': 0.0,
#   'model_year': 2000,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 130,
#   'num_cylinders': 4.0,
#   'horsepower': 139.0,
#   'vehicle_weight': 2761.532593193572,
#   'acceleration': 18.0,
#   'model_year': 2002,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 4.0,
#   'horsepower': 145.0,
#   'vehicle_weight': 2609.402780982518,
#   'acceleration': 20.1,
#   'model_year': 2000,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 2.0,
#   'horsepower': 110.0,
#   'vehicle_weight': 2971.2145745989487,
#   'acceleration': 0.0,
#   'model_year': 2003,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 0.0,
#   'horsepower': 170.0,
#   'vehicle_weight': 3383.5834036204187,
#   'acceleration': 14.0,
#   'model_year': 2009,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 6.0,
#   'horsepower': 155.0,
#   'vehicle_weight': 3516.828074929168,
#   'acceleration': 0.0,
#   'model_year': 2006,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 4.0,
#   'horsepower': 109.0,
#   'vehicle_weight': 3544.2087684758712,
#   'acceleration': 11.5,
#   'model_year': 2009,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 4.0,
#   'horsepower': 127.0,
#   'vehicle_weight': 3289.609764827081,
#   'acceleration': 14.7,
#   'model_year': 2020,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 3.0,
#   'horsepower': 137.0,
#   'vehicle_weight': 4023.2272336895608,
#   'acceleration': 14.1,
#   'model_year': 2010,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 8.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3055.616666060788,
#   'acceleration': 15.5,
#   'model_year': 2015,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 0.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2378.8726184029383,
#   'acceleration': 17.6,
#   'model_year': 2004,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 4.0,
#   'horsepower': 181.0,
#   'vehicle_weight': 3506.590509751147,
#   'acceleration': 17.2,
#   'model_year': 2022,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 3.0,
#   'horsepower': 170.0,
#   'vehicle_weight': 3267.193823800575,
#   'acceleration': 14.3,
#   'model_year': 2008,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 5.0,
#   'horsepower': 183.0,
#   'vehicle_weight': 3619.0473434098926,
#   'acceleration': 15.9,
#   'model_year': 2015,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 6.0,
#   'horsepower': 163.0,
#   'vehicle_weight': 3151.026722672367,
#   'acceleration': 14.3,
#   'model_year': 2012,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 2.0,
#   'horsepower': 133.0,
#   'vehicle_weight': 2761.303964729023,
#   'acceleration': 12.6,
#   'model_year': 2015,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 5.0,
#   'horsepower': 150.0,
#   'vehicle_weight': 2243.6039661907853,
#   'acceleration': 16.6,
#   'model_year': 2002,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 5.0,
#   'horsepower': 151.0,
#   'vehicle_weight': 3535.451417992528,
#   'acceleration': 11.0,
#   'model_year': 2010,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 2.0,
#   'horsepower': 97.0,
#   'vehicle_weight': 2375.4088803028208,
#   'acceleration': 13.9,
#   'model_year': 2010,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 3.0,
#   'horsepower': 120.0,
#   'vehicle_weight': 3334.9288229578187,
#   'acceleration': 14.5,
#   'model_year': 2017,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 4.0,
#   'horsepower': 95.0,
#   'vehicle_weight': 2746.045637855605,
#   'acceleration': 19.0,
#   'model_year': 2007,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 4.0,
#   'horsepower': 164.0,
#   'vehicle_weight': 2495.8112612410373,
#   'acceleration': 15.9,
#   'model_year': 2014,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 4.0,
#   'horsepower': 140.0,
#   'vehicle_weight': 3549.877874801432,
#   'acceleration': 14.8,
#   'model_year': 2021,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 3.0,
#   'horsepower': 146.0,
#   'vehicle_weight': 2670.619668664752,
#   'acceleration': 15.0,
#   'model_year': 2012,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 0.0,
#   'horsepower': 129.0,
#   'vehicle_weight': 1976.301608976604,
#   'acceleration': 16.3,
#   'model_year': 2014,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 3.0,
#   'horsepower': 120.0,
#   'vehicle_weight': 2577.38408928056,
#   'acceleration': 0.0,
#   'model_year': 2014,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 3.0,
#   'horsepower': 176.0,
#   'vehicle_weight': 3392.9513586627854,
#   'acceleration': 16.8,
#   'model_year': 2001,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 1.0,
#   'horsepower': 141.0,
#   'vehicle_weight': 1880.3043056165127,
#   'acceleration': 18.6,
#   'model_year': 2013,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 0.0,
#   'horsepower': 163.0,
#   'vehicle_weight': 3369.7549334459886,
#   'acceleration': 0.0,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 2.0,
#   'horsepower': 124.0,
#   'vehicle_weight': 2908.8666598296195,
#   'acceleration': 15.3,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 130,
#   'num_cylinders': 0.0,
#   'horsepower': 127.0,
#   'vehicle_weight': 3004.1683963289365,
#   'acceleration': 0.0,
#   'model_year': 2007,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 1.0,
#   'horsepower': 89.0,
#   'vehicle_weight': 2479.943692907553,
#   'acceleration': 12.5,
#   'model_year': 2014,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 3.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3211.426524330027,
#   'acceleration': 0.0,
#   'model_year': 2003,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 4.0,
#   'horsepower': 148.0,
#   'vehicle_weight': 3711.603564804736,
#   'acceleration': 16.8,
#   'model_year': 2003,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 9.0,
#   'horsepower': 191.0,
#   'vehicle_weight': 3575.221918608757,
#   'acceleration': 12.5,
#   'model_year': 2008,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 2.0,
#   'horsepower': 148.0,
#   'vehicle_weight': 2771.8069019198483,
#   'acceleration': 18.0,
#   'model_year': 2003,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 5.0,
#   'horsepower': 123.0,
#   'vehicle_weight': 2805.6665646718966,
#   'acceleration': 16.9,
#   'model_year': 2021,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 280,
#   'num_cylinders': 4.0,
#   'horsepower': 148.0,
#   'vehicle_weight': 2611.17297003633,
#   'acceleration': 17.2,
#   'model_year': 2007,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 4.0,
#   'horsepower': 146.0,
#   'vehicle_weight': 2330.8578647238314,
#   'acceleration': 16.6,
#   'model_year': 2008,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 1.0,
#   'horsepower': 141.0,
#   'vehicle_weight': 3319.236265690127,
#   'acceleration': 13.3,
#   'model_year': 2021,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 5.0,
#   'horsepower': 179.0,
#   'vehicle_weight': 2762.833549611767,
#   'acceleration': 12.7,
#   'model_year': 2010,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 7.0,
#   'horsepower': 220.0,
#   'vehicle_weight': 3221.900600395318,
#   'acceleration': 12.5,
#   'model_year': 2001,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 3.0,
#   'horsepower': 123.0,
#   'vehicle_weight': 2517.2161641573425,
#   'acceleration': 16.2,
#   'model_year': 2018,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 3.0,
#   'horsepower': 128.0,
#   'vehicle_weight': 2831.991412735697,
#   'acceleration': 13.5,
#   'model_year': 2002,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 2.0,
#   'horsepower': 117.0,
#   'vehicle_weight': 3087.4196086315405,
#   'acceleration': 0.0,
#   'model_year': 2005,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 4.0,
#   'horsepower': 153.0,
#   'vehicle_weight': 3343.8494255087403,
#   'acceleration': 16.2,
#   'model_year': 2004,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 3.0,
#   'horsepower': 148.0,
#   'vehicle_weight': 3136.4779005762334,
#   'acceleration': 15.5,
#   'model_year': 2003,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 0.0,
#   'horsepower': 157.0,
#   'vehicle_weight': 3628.510737983589,
#   'acceleration': 17.1,
#   'model_year': 2018,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 5.0,
#   'horsepower': 105.0,
#   'vehicle_weight': 2757.3374227823765,
#   'acceleration': 19.1,
#   'model_year': 2019,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 1.0,
#   'horsepower': 170.0,
#   'vehicle_weight': 3316.141057077854,
#   'acceleration': 11.5,
#   'model_year': 2012,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 4.0,
#   'horsepower': 141.0,
#   'vehicle_weight': 4116.351836187175,
#   'acceleration': 17.9,
#   'model_year': 2009,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 3.0,
#   'horsepower': 173.0,
#   'vehicle_weight': 3036.320949960771,
#   'acceleration': 14.2,
#   'model_year': 2011,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 4.0,
#   'horsepower': 134.0,
#   'vehicle_weight': 3362.578666057142,
#   'acceleration': 14.2,
#   'model_year': 2013,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 110,
#   'num_cylinders': 6.0,
#   'horsepower': 146.0,
#   'vehicle_weight': 3320.857699947679,
#   'acceleration': 16.5,
#   'model_year': 2016,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 5.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2673.6773144136087,
#   'acceleration': 14.4,
#   'model_year': 2002,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 6.0,
#   'horsepower': 152.0,
#   'vehicle_weight': 3251.1039710543023,
#   'acceleration': 12.5,
#   'model_year': 2018,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 4.0,
#   'horsepower': 126.0,
#   'vehicle_weight': 3565.483939823969,
#   'acceleration': 17.0,
#   'model_year': 2008,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 120,
#   'num_cylinders': 6.0,
#   'horsepower': 158.0,
#   'vehicle_weight': 2921.7891713038907,
#   'acceleration': 15.3,
#   'model_year': 2007,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 7.0,
#   'horsepower': 99.0,
#   'vehicle_weight': 3602.664482911108,
#   'acceleration': 17.0,
#   'model_year': 2015,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 1.0,
#   'horsepower': 115.0,
#   'vehicle_weight': 2902.7860167043414,
#   'acceleration': 14.2,
#   'model_year': 2011,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 10.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2765.2684461242297,
#   'acceleration': 19.0,
#   'model_year': 2022,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 0.0,
#   'horsepower': 141.0,
#   'vehicle_weight': 3855.191033494997,
#   'acceleration': 10.5,
#   'model_year': 2010,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 6.0,
#   'horsepower': 203.0,
#   'vehicle_weight': 2797.69492031825,
#   'acceleration': 13.2,
#   'model_year': 2009,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 4.0,
#   'horsepower': 200.0,
#   'vehicle_weight': 2617.509467603427,
#   'acceleration': 13.2,
#   'model_year': 2022,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 3.0,
#   'horsepower': 124.0,
#   'vehicle_weight': 3409.1027035279976,
#   'acceleration': 13.6,
#   'model_year': 2006,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 3.0,
#   'horsepower': 171.0,
#   'vehicle_weight': 3399.8020531813318,
#   'acceleration': 13.7,
#   'model_year': 2020,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 4.0,
#   'horsepower': 186.0,
#   'vehicle_weight': 3689.4500446358015,
#   'acceleration': 14.1,
#   'model_year': 2015,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 3.0,
#   'horsepower': 119.0,
#   'vehicle_weight': 3320.509431238896,
#   'acceleration': 15.5,
#   'model_year': 2002,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 3.0,
#   'horsepower': 147.0,
#   'vehicle_weight': 3310.9239209462908,
#   'acceleration': 9.3,
#   'model_year': 2020,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 0.0,
#   'horsepower': 164.0,
#   'vehicle_weight': 3507.599434508528,
#   'acceleration': 14.9,
#   'model_year': 2002,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 280,
#   'num_cylinders': 3.0,
#   'horsepower': 94.0,
#   'vehicle_weight': 2854.2450753688645,
#   'acceleration': 0.0,
#   'model_year': 2004,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 4.0,
#   'horsepower': 180.0,
#   'vehicle_weight': 4552.98359980908,
#   'acceleration': 15.5,
#   'model_year': 2017,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 0.0,
#   'horsepower': 99.0,
#   'vehicle_weight': 2931.957819249301,
#   'acceleration': 15.2,
#   'model_year': 2013,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 2.0,
#   'horsepower': 133.0,
#   'vehicle_weight': 3995.950711561359,
#   'acceleration': 16.6,
#   'model_year': 2021,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 4.0,
#   'horsepower': 175.0,
#   'vehicle_weight': 2947.978487414321,
#   'acceleration': 15.1,
#   'model_year': 2002,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 0.0,
#   'horsepower': 116.0,
#   'vehicle_weight': 2684.925170933768,
#   'acceleration': 12.0,
#   'model_year': 2020,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 0.0,
#   'horsepower': 129.0,
#   'vehicle_weight': 2823.041894737696,
#   'acceleration': 10.4,
#   'model_year': 2011,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 6.0,
#   'horsepower': 139.0,
#   'vehicle_weight': 2554.858220224446,
#   'acceleration': 16.2,
#   'model_year': 2003,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 2.0,
#   'horsepower': 163.0,
#   'vehicle_weight': 3380.8415464394884,
#   'acceleration': 17.1,
#   'model_year': 2008,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 4.0,
#   'horsepower': 106.0,
#   'vehicle_weight': 1702.2421019875094,
#   'acceleration': 12.8,
#   'model_year': 2004,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 4.0,
#   'horsepower': 151.0,
#   'vehicle_weight': 2843.486180405409,
#   'acceleration': 9.2,
#   'model_year': 2020,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 320,
#   'num_cylinders': 0.0,
#   'horsepower': 143.0,
#   'vehicle_weight': 3292.7678108858936,
#   'acceleration': 10.6,
#   'model_year': 2006,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 1.0,
#   'horsepower': 174.0,
#   'vehicle_weight': 3458.2873880957395,
#   'acceleration': 15.8,
#   'model_year': 2022,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 4.0,
#   'horsepower': 187.0,
#   'vehicle_weight': 2634.006244148779,
#   'acceleration': 14.7,
#   'model_year': 2007,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 6.0,
#   'horsepower': 162.0,
#   'vehicle_weight': 2542.1220099505786,
#   'acceleration': 19.0,
#   'model_year': 2015,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 2.0,
#   'horsepower': 196.0,
#   'vehicle_weight': 2076.845420756184,
#   'acceleration': 12.6,
#   'model_year': 2017,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 5.0,
#   'horsepower': 141.0,
#   'vehicle_weight': 2927.067238438163,
#   'acceleration': 17.0,
#   'model_year': 2003,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 6.0,
#   'horsepower': 89.0,
#   'vehicle_weight': 3466.126490802176,
#   'acceleration': 11.3,
#   'model_year': 2022,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 6.0,
#   'horsepower': 160.0,
#   'vehicle_weight': 3045.7925913651584,
#   'acceleration': 15.7,
#   'model_year': 2001,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 120,
#   'num_cylinders': 1.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 4117.358423695604,
#   'acceleration': 15.7,
#   'model_year': 2004,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 5.0,
#   'horsepower': 185.0,
#   'vehicle_weight': 2925.8835946322506,
#   'acceleration': 16.0,
#   'model_year': 2022,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 4.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2908.029610770682,
#   'acceleration': 15.7,
#   'model_year': 2014,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 5.0,
#   'horsepower': 164.0,
#   'vehicle_weight': 2981.107371272218,
#   'acceleration': 17.3,
#   'model_year': 2013,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 110,
#   'num_cylinders': 1.0,
#   'horsepower': 139.0,
#   'vehicle_weight': 2622.1545895888867,
#   'acceleration': 16.0,
#   'model_year': 2003,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 5.0,
#   'horsepower': 156.0,
#   'vehicle_weight': 2630.2375720986256,
#   'acceleration': 14.4,
#   'model_year': 2013,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 0.0,
#   'horsepower': 126.0,
#   'vehicle_weight': 2996.8027928658603,
#   'acceleration': 14.6,
#   'model_year': 2009,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 3.0,
#   'horsepower': 147.0,
#   'vehicle_weight': 2508.0736995850484,
#   'acceleration': 19.1,
#   'model_year': 2014,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 6.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3034.275905472262,
#   'acceleration': 16.6,
#   'model_year': 2022,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 4.0,
#   'horsepower': 139.0,
#   'vehicle_weight': 2201.9394002834792,
#   'acceleration': 18.0,
#   'model_year': 2009,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 4.0,
#   'horsepower': 134.0,
#   'vehicle_weight': 3164.584787705145,
#   'acceleration': 15.8,
#   'model_year': 2018,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 3.0,
#   'horsepower': 144.0,
#   'vehicle_weight': 2873.8096954905545,
#   'acceleration': 12.8,
#   'model_year': 2021,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 120,
#   'num_cylinders': 6.0,
#   'horsepower': 123.0,
#   'vehicle_weight': 2806.9937006469186,
#   'acceleration': 14.8,
#   'model_year': 2021,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 1.0,
#   'horsepower': 151.0,
#   'vehicle_weight': 3657.145231807114,
#   'acceleration': 13.8,
#   'model_year': 2011,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 0.0,
#   'horsepower': 150.0,
#   'vehicle_weight': 3193.9812500326907,
#   'acceleration': 19.1,
#   'model_year': 2004,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 6.0,
#   'horsepower': 157.0,
#   'vehicle_weight': 2617.831529667573,
#   'acceleration': 13.1,
#   'model_year': 2000,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 1.0,
#   'horsepower': 171.0,
#   'vehicle_weight': 3046.1367877590897,
#   'acceleration': 15.6,
#   'model_year': 2016,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 6.0,
#   'horsepower': 135.0,
#   'vehicle_weight': 3166.572217516273,
#   'acceleration': 13.1,
#   'model_year': 2013,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 300,
#   'num_cylinders': 3.0,
#   'horsepower': 159.0,
#   'vehicle_weight': 3025.5611147839218,
#   'acceleration': 17.7,
#   'model_year': 2011,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 4.0,
#   'horsepower': 170.0,
#   'vehicle_weight': 2991.923276482039,
#   'acceleration': 14.1,
#   'model_year': 2016,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 3.0,
#   'horsepower': 139.0,
#   'vehicle_weight': 3346.29020673348,
#   'acceleration': 14.0,
#   'model_year': 2015,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 6.0,
#   'horsepower': 174.0,
#   'vehicle_weight': 3980.2158231291687,
#   'acceleration': 15.9,
#   'model_year': 2002,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 10.0,
#   'horsepower': 116.0,
#   'vehicle_weight': 2396.9686477329096,
#   'acceleration': 14.7,
#   'model_year': 2017,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 4.0,
#   'horsepower': 149.0,
#   'vehicle_weight': 2869.157863879449,
#   'acceleration': 14.7,
#   'model_year': 2000,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 7.0,
#   'horsepower': 172.0,
#   'vehicle_weight': 3009.8528151365595,
#   'acceleration': 13.1,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 0.0,
#   'horsepower': 127.0,
#   'vehicle_weight': 2874.8654523885675,
#   'acceleration': 21.6,
#   'model_year': 2020,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 0.0,
#   'horsepower': 92.0,
#   'vehicle_weight': 3859.055028198238,
#   'acceleration': 17.5,
#   'model_year': 2021,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 4.0,
#   'horsepower': 148.0,
#   'vehicle_weight': 2150.5301758567066,
#   'acceleration': 15.0,
#   'model_year': 2010,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 2.0,
#   'horsepower': 157.0,
#   'vehicle_weight': 3882.958551570783,
#   'acceleration': 15.5,
#   'model_year': 2014,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 280,
#   'num_cylinders': 4.0,
#   'horsepower': 148.0,
#   'vehicle_weight': 3394.0988111682245,
#   'acceleration': 14.5,
#   'model_year': 2005,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 280,
#   'num_cylinders': 5.0,
#   'horsepower': 131.0,
# ...
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 5.0,
#   'horsepower': 114.0,
#   'vehicle_weight': 2997.415861162281,
#   'acceleration': 14.7,
#   'model_year': 2001,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 3.0,
#   'horsepower': 99.0,
#   'vehicle_weight': 2747.322313848241,
#   'acceleration': 13.1,
#   'model_year': 2006,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 290,
#   'num_cylinders': 2.0,
#   'horsepower': 130.0,
#   'vehicle_weight': 3209.56819613546,
#   'acceleration': 0.0,
#   'model_year': 2010,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 3.0,
#   'horsepower': 155.0,
#   'vehicle_weight': 2914.731661272499,
#   'acceleration': 12.2,
#   'model_year': 2009,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 4.0,
#   'horsepower': 134.0,
#   'vehicle_weight': 2834.873453109252,
#   'acceleration': 14.8,
#   'model_year': 2015,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 110,
#   'num_cylinders': 4.0,
#   'horsepower': 127.0,
#   'vehicle_weight': 2925.0322440781347,
#   'acceleration': 14.7,
#   'model_year': 2016,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 1.0,
#   'horsepower': 138.0,
#   'vehicle_weight': 2588.313722323945,
#   'acceleration': 13.2,
#   'model_year': 2009,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 5.0,
#   'horsepower': 146.0,
#   'vehicle_weight': 2838.510966543043,
#   'acceleration': 12.4,
#   'model_year': 2008,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 3.0,
#   'horsepower': 112.0,
#   'vehicle_weight': 3488.9116998855293,
#   'acceleration': 9.2,
#   'model_year': 2005,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 1.0,
#   'horsepower': 128.0,
#   'vehicle_weight': 2940.178346516776,
#   'acceleration': 16.7,
#   'model_year': 2013,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 3.0,
#   'horsepower': 109.0,
#   'vehicle_weight': 3555.175913666742,
#   'acceleration': 0.0,
#   'model_year': 2004,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 5.0,
#   'horsepower': 102.0,
#   'vehicle_weight': 2793.5076992326435,
#   'acceleration': 20.1,
#   'model_year': 2020,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 1.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3202.990192717986,
#   'acceleration': 14.5,
#   'model_year': 2000,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 130,
#   'num_cylinders': 0.0,
#   'horsepower': 136.0,
#   'vehicle_weight': 3417.849111215685,
#   'acceleration': 0.0,
#   'model_year': 2023,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 130,
#   'num_cylinders': 4.0,
#   'horsepower': 180.0,
#   'vehicle_weight': 2334.9828278226105,
#   'acceleration': 14.9,
#   'model_year': 2021,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 4.0,
#   'horsepower': 177.0,
#   'vehicle_weight': 3693.3766151794175,
#   'acceleration': 0.0,
#   'model_year': 2003,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 4.0,
#   'horsepower': 164.0,
#   'vehicle_weight': 2550.511831651488,
#   'acceleration': 0.0,
#   'model_year': 2021,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 280,
#   'num_cylinders': 0.0,
#   'horsepower': 113.0,
#   'vehicle_weight': 2503.09025678955,
#   'acceleration': 15.0,
#   'model_year': 2002,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 3.0,
#   'horsepower': 166.0,
#   'vehicle_weight': 3085.9105244766497,
#   'acceleration': 12.3,
#   'model_year': 2010,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 4.0,
#   'horsepower': 100.0,
#   'vehicle_weight': 3073.153323302858,
#   'acceleration': 17.0,
#   'model_year': 2006,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 3.0,
#   'horsepower': 119.0,
#   'vehicle_weight': 3084.6104547581226,
#   'acceleration': 15.1,
#   'model_year': 2011,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 3.0,
#   'horsepower': 160.0,
#   'vehicle_weight': 2836.5298197739858,
#   'acceleration': 11.4,
#   'model_year': 2016,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 2.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2625.834992253509,
#   'acceleration': 0.0,
#   'model_year': 2000,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 3.0,
#   'horsepower': 188.0,
#   'vehicle_weight': 3852.38576503503,
#   'acceleration': 15.8,
#   'model_year': 2008,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 2.0,
#   'horsepower': 132.0,
#   'vehicle_weight': 2904.0663153145188,
#   'acceleration': 0.0,
#   'model_year': 2006,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 4.0,
#   'horsepower': 176.0,
#   'vehicle_weight': 2511.9951274881764,
#   'acceleration': 17.9,
#   'model_year': 2005,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 120,
#   'num_cylinders': 5.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2812.364875287527,
#   'acceleration': 13.8,
#   'model_year': 2017,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 140,
#   'num_cylinders': 5.0,
#   'horsepower': 121.0,
#   'vehicle_weight': 2568.678483369127,
#   'acceleration': 16.1,
#   'model_year': 2020,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 120,
#   'num_cylinders': 3.0,
#   'horsepower': 141.0,
#   'vehicle_weight': 2999.683392141089,
#   'acceleration': 14.2,
#   'model_year': 2021,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 4.0,
#   'horsepower': 89.0,
#   'vehicle_weight': 3442.9161353448303,
#   'acceleration': 13.7,
#   'model_year': 2010,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 3.0,
#   'horsepower': 139.0,
#   'vehicle_weight': 3251.1664944091617,
#   'acceleration': 14.5,
#   'model_year': 2019,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 9.0,
#   'horsepower': 100.0,
#   'vehicle_weight': 2881.171703305993,
#   'acceleration': 13.1,
#   'model_year': 2013,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 0.0,
#   'horsepower': 169.0,
#   'vehicle_weight': 3090.88507501632,
#   'acceleration': 11.1,
#   'model_year': 2020,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 2.0,
#   'horsepower': 89.0,
#   'vehicle_weight': 2763.869029680765,
#   'acceleration': 15.9,
#   'model_year': 2000,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 240,
#   'num_cylinders': 4.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2913.7197804828843,
#   'acceleration': 11.5,
#   'model_year': 2021,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 1.0,
#   'horsepower': 111.0,
#   'vehicle_weight': 2420.334759776833,
#   'acceleration': 15.2,
#   'model_year': 2004,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 2.0,
#   'horsepower': 176.0,
#   'vehicle_weight': 3456.729127749659,
#   'acceleration': 12.4,
#   'model_year': 2017,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 250,
#   'num_cylinders': 2.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2128.7395150975763,
#   'acceleration': 14.6,
#   'model_year': 2007,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 1.0,
#   'horsepower': 127.0,
#   'vehicle_weight': 2629.111438162986,
#   'acceleration': 16.1,
#   'model_year': 2001,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 6.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3255.300417036049,
#   'acceleration': 18.4,
#   'model_year': 2008,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 1.0,
#   'horsepower': 195.0,
#   'vehicle_weight': 2322.3555863795928,
#   'acceleration': 17.6,
#   'model_year': 2005,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 0.0,
#   'horsepower': 136.0,
#   'vehicle_weight': 2494.7899685345774,
#   'acceleration': 15.8,
#   'model_year': 2011,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 200,
#   'num_cylinders': 5.0,
#   'horsepower': 170.0,
#   'vehicle_weight': 2865.775377181484,
#   'acceleration': 11.0,
#   'model_year': 2005,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 5.0,
#   'horsepower': 131.0,
#   'vehicle_weight': 2787.420526167132,
#   'acceleration': 13.9,
#   'model_year': 2011,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 2.0,
#   'horsepower': 129.0,
#   'vehicle_weight': 3749.153245921249,
#   'acceleration': 15.5,
#   'model_year': 2013,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 2.0,
#   'horsepower': 209.0,
#   'vehicle_weight': 3760.420887088718,
#   'acceleration': 16.4,
#   'model_year': 2019,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 2.0,
#   'horsepower': 171.0,
#   'vehicle_weight': 3119.005765643992,
#   'acceleration': 11.8,
#   'model_year': 2015,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 270,
#   'num_cylinders': 5.0,
#   'horsepower': 106.0,
#   'vehicle_weight': 1913.0343242992185,
#   'acceleration': 11.2,
#   'model_year': 2002,
#   'origin': 'Europe',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 3.0,
#   'horsepower': 163.0,
#   'vehicle_weight': 3501.9051243253366,
#   'acceleration': 14.8,
#   'model_year': 2009,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 160,
#   'num_cylinders': 3.0,
#   'horsepower': 151.0,
#   'vehicle_weight': 3611.5172104592993,
#   'acceleration': 11.6,
#   'model_year': 2019,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 5.0,
#   'horsepower': 113.0,
#   'vehicle_weight': 3390.363621557051,
#   'acceleration': 20.7,
#   'model_year': 2005,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 210,
#   'num_cylinders': 3.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 2195.928478254098,
#   'acceleration': 15.3,
#   'model_year': 2016,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 3.0,
#   'horsepower': 142.0,
#   'vehicle_weight': 2250.112436346235,
#   'acceleration': 14.6,
#   'model_year': 2018,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 5.0,
#   'horsepower': 198.0,
#   'vehicle_weight': 2904.9125553767462,
#   'acceleration': 14.0,
#   'model_year': 2006,
#   'origin': 'Asia',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 110,
#   'num_cylinders': 7.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3262.842248646735,
#   'acceleration': 12.4,
#   'model_year': 2011,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 4.0,
#   'horsepower': 189.0,
#   'vehicle_weight': 3399.697410194452,
#   'acceleration': 14.2,
#   'model_year': 2005,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 170,
#   'num_cylinders': 8.0,
#   'horsepower': 188.0,
#   'vehicle_weight': 2797.526251187545,
#   'acceleration': 14.4,
#   'model_year': 2019,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 190,
#   'num_cylinders': 5.0,
#   'horsepower': 180.0,
#   'vehicle_weight': 2799.303563270548,
#   'acceleration': 16.4,
#   'model_year': 2002,
#   'origin': 'USA',
#   'fuel_type': 'Diesel',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 230,
#   'num_cylinders': 1.0,
#   'horsepower': 75.0,
#   'vehicle_weight': 2986.515812242064,
#   'acceleration': 0.0,
#   'model_year': 2004,
#   'origin': 'Europe',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 7.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 3269.337601614688,
#   'acceleration': 0.0,
#   'model_year': 2008,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 150,
#   'num_cylinders': 2.0,
#   'horsepower': 145.0,
#   'vehicle_weight': 2708.854043856324,
#   'acceleration': 14.1,
#   'model_year': 2003,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 260,
#   'num_cylinders': 2.0,
#   'horsepower': 0.0,
#   'vehicle_weight': 4039.372630266043,
#   'acceleration': 11.8,
#   'model_year': 2012,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 220,
#   'num_cylinders': 3.0,
#   'horsepower': 190.0,
#   'vehicle_weight': 4078.453157459211,
#   'acceleration': 0.0,
#   'model_year': 2012,
#   'origin': 'Asia',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'All-wheel drive'},
#  {'engine_displacement': 180,
#   'num_cylinders': 2.0,
#   'horsepower': 157.0,
#   'vehicle_weight': 2643.938273009878,
#   'acceleration': 14.1,
#   'model_year': 2018,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  {'engine_displacement': 90,
#   'num_cylinders': 5.0,
#   'horsepower': 213.0,
#   'vehicle_weight': 2812.0089879336138,
#   'acceleration': 18.2,
#   'model_year': 2018,
#   'origin': 'USA',
#   'fuel_type': 'Gasoline',
#   'drivetrain': 'Front-wheel drive'},
#  ...]

# %%
X_val = dv.transform(val_dicts)

# %%
from sklearn.tree import export_text

# %%
print(export_text(dt,feature_names=dv.get_feature_names_out()))
# Out:
# |--- vehicle_weight <= 3022.11
# |   |--- value: [16.88]
# |--- vehicle_weight >  3022.11
# |   |--- value: [12.94]

# %% [markdown]
# ## question 2
# train random forest and find rmse

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=10,random_state=1,n_jobs=-1)
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=10, n_jobs=-1, random_state=1)

# %%
y_pred = rf.predict(X_val)

# %%
mean_squared_error(y_pred,y_val)
# Out:
# 0.21232989553299916

# %%
scores=[]
for n in range(10,200,10):
    rf = RandomForestRegressor(n_estimators=n,random_state=1)
    rf.fit(X_train,y_train)

    y_pred=rf.predict(X_val)
    auc= mean_squared_error(y_val,y_pred)    
    scores.append((n,auc))

# %%
df_scores = pd.DataFrame(scores,columns=['n_estimators','auc'])
df_scores
# Out:
#     n_estimators       auc
# 0             10  0.212330
# 1             20  0.205932
# 2             30  0.203859
# 3             40  0.201236
# 4             50  0.199685
# 5             60  0.198931
# 6             70  0.198456
# 7             80  0.198220
# 8             90  0.198295
# 9            100  0.198159
# 10           110  0.197510
# 11           120  0.197530
# 12           130  0.197290
# 13           140  0.197081
# 14           150  0.196739
# 15           160  0.196411
# 16           170  0.196378
# 17           180  0.196005
# 18           190  0.196123

# %%
df_scores.sort_values('auc')
# Out:
#     n_estimators       auc
# 17           180  0.196005
# 18           190  0.196123
# 16           170  0.196378
# 15           160  0.196411
# 14           150  0.196739
# 13           140  0.197081
# 12           130  0.197290
# 10           110  0.197510
# 11           120  0.197530
# 9            100  0.198159
# 7             80  0.198220
# 8             90  0.198295
# 6             70  0.198456
# 5             60  0.198931
# 4             50  0.199685
# 3             40  0.201236
# 2             30  0.203859
# 1             20  0.205932
# 0             10  0.212330

# %% [markdown]
# ## here the 180th n_estimators has lowest rmsc

# %%
plt.plot(df_scores.n_estimators,df_scores.auc)

# %% [markdown]
# ## now find the best max_depth

# %%
scores=[]
for d in [5,10,15,20,25]:
 for n in range(10,201,10):
    rf = RandomForestRegressor(n_estimators=n,max_depth=d,random_state=1,n_jobs=-1)
    rf.fit(X_train,y_train)

    y_pred=rf.predict(X_val)
    auc= mean_squared_error(y_val,y_pred)    
    scores.append((n,d,auc))

# %%
column=['n_estimators','max_depth','RMSE']
df_scores = pd.DataFrame(scores,columns=column)
df_scores.head()
# Out:
#    n_estimators  max_depth      RMSE
# 0            10          5  0.254822
# 1            20          5  0.253820
# 2            30          5  0.252565
# 3            40          5  0.251776
# 4            50          5  0.251583

# %%
df_scores.sort_values('RMSE')
# Out:
#     n_estimators  max_depth      RMSE
# 37           180         10  0.193298
# 39           200         10  0.193373
# 38           190         10  0.193412
# 35           160         10  0.193465
# 36           170         10  0.193492
# ..           ...        ...       ...
# 16           170          5  0.251721
# 3             40          5  0.251776
# 2             30          5  0.252565
# 1             20          5  0.253820
# 0             10          5  0.254822
#
# [100 rows x 3 columns]

# %% [markdown]
# ## so the best max_depth is 10

# %%
rf = RandomForestRegressor(n_estimators=10,max_depth=20,random_state=1,n_jobs=-1)
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=20, n_estimators=10, n_jobs=-1, random_state=1)

# %%
rf.feature_importances_
# Out:
# array([1.17788447e-02, 3.36749448e-04, 4.05213902e-04, 3.45195688e-03,
#        3.47667795e-04, 3.67703216e-04, 1.62642739e-02, 3.50031263e-03,
#        2.53719850e-03, 4.78575907e-04, 5.56067031e-04, 5.39523961e-04,
#        9.59435912e-01])

# %%
dv.get_feature_names_out()
# Out:
# array(['acceleration', 'drivetrain=All-wheel drive',
#        'drivetrain=Front-wheel drive', 'engine_displacement',
#        'fuel_type=Diesel', 'fuel_type=Gasoline', 'horsepower',
#        'model_year', 'num_cylinders', 'origin=Asia', 'origin=Europe',
#        'origin=USA', 'vehicle_weight'], dtype=object)

# %% [markdown]
# ## vehicle_weinght is the most important feature

# %%
import xgboost as xgb

# %%
feature = dv.get_feature_names_out().tolist()
dtrain = xgb.DMatrix(X_train,label=y_train,feature_names=feature)
dval = xgb.DMatrix(X_val,label=y_val,feature_names=feature)

# %%
xgb_params = {
    'eta': 0.3, 
    'max_depth': 6,
    'min_child_weight': 1,
    
    'objective': 'reg:squarederror',
    'nthread': 8,
    
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params,dtrain,num_boost_round=10)

# %%
y_pred = model.predict(dval)

# %%
mean_squared_error(y_val,y_pred)
# Out:
# 0.19895188197051858

# %%
xgb_params = {
    'eta': 0.1, 
    'max_depth': 6,
    'min_child_weight': 1,
    
    'objective': 'reg:squarederror',
    'nthread': 8,
    
    'seed': 1,
    'verbosity': 1,
}
model = xgb.train(xgb_params,dtrain,num_boost_round=10)

# %%
y_pred = model.predict(dval)

# %%
mean_squared_error(y_val,y_pred)
# Out:
# 1.0394787515689756

# %% [markdown]
# eta:0.3 is leads to best RMSE
